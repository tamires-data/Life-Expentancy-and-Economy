# %% [markdown]
# # Learning Pandas
# # Objectives
# - Setup
# - Setup
# - Loading data
# - Inspect / Sort / Filter data
# - Analytical functions

# %% [markdown]
# ## Functions used:
# - data.index returns information about the index.
# - data.info () returns information about the types and numbers of non-null observations in the DataFrame.
# - data.describe () returns some descriptive statistics (count, mean, std, min, 25%, 50%, 75%, max) regarding the numerical columns of the DataFrame
# - data.sort_values() order the values in a ascending way,“Ascending” is True by default, ie, the lowest value first
# - data.iloc allows you to select rows (and optionally columns) by position (ie, by row number).
# - idxmax or idxmin will return the index of the line where the first minimum / maximum is found.
# - grouṕ.by() group our data and calculate indicators for individual groups

# %% [markdown]
# ###  How Sovereign Debt are related to these variables?

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [10,8]  # Set default figure size
import requests

from IPython.core.display import display, HTML #set preferences of view
display(HTML("<style>.container {width:90% !important;}</style>"))
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 8)
# Out:
# <style>.container {width:90% !important;}</style>

# %%
 data= pd.read_csv('lifeexpentacy.csv') 
 data
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# ...           ...   ...          ...                 ...             ...
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1702     Zimbabwe  2017     3.638300            7.549491        0.754147
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                            50.799999                      0.718114
# 1                            51.200001                      0.678896
# 2                            51.599998                      0.600127
# 3                            51.919998                      0.495901
# ...                                ...                           ...
# 1700                         53.799999                      0.667193
# 1701                         54.400002                      0.732971
# 1702                         55.000000                      0.752826
# 1703                         55.599998                      0.762675
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 0       0.177889                   0.881686         0.517637         0.258195
# 1       0.200178                   0.850035         0.583926         0.237092
# 2       0.134353                   0.706766         0.618265         0.275324
# 3       0.172137                   0.731109         0.611387         0.267175
# ...          ...                        ...              ...              ...
# 1700   -0.097354                   0.810457         0.715079         0.178861
# 1701   -0.068105                   0.723612         0.737636         0.208555
# 1702   -0.069670                   0.751208         0.806428         0.224051
# 1703   -0.038384                   0.844209         0.710119         0.211726
#
#       Confidence in national government  Democratic Quality  Delivery Quality  \
# 0                              0.612072           -1.929690         -1.655084
# 1                              0.611545           -2.044093         -1.635025
# 2                              0.299357           -1.991810         -1.617176
# 3                              0.307386           -1.919018         -1.616221
# ...                                 ...                 ...               ...
# 1700                           0.590012           -0.893078         -1.357514
# 1701                           0.699344           -0.900649         -1.374650
# 1702                           0.682647           -0.988153         -1.350867
# 1703                           0.550508                 NaN               NaN
#
#       Standard deviation of ladder by country-year  \
# 0                                         1.774662
# 1                                         1.722688
# 2                                         1.878622
# 3                                         1.785360
# ...                                            ...
# 1700                                      2.198865
# 1701                                      2.776363
# 1702                                      2.656848
# 1703                                      2.498696
#
#       Standard deviation/Mean of ladder by country-year  \
# 0                                              0.476600
# 1                                              0.391362
# 2                                              0.394803
# 3                                              0.465942
# ...                                                 ...
# 1700                                           0.593776
# 1701                                           0.743257
# 1702                                           0.730244
# 1703                                           0.690919
#
#       GINI index (World Bank estimate)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# ...                                ...
# 1700                               NaN
# 1701                               NaN
# 1702                               NaN
# 1703                               NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...                                                 ...
# 1700                                              0.432
# 1701                                              0.432
# 1702                                              0.432
# 1703                                              0.432
#
#       gini of household income reported in Gallup, by wp5-year  \
# 0                                                   NaN
# 1                                              0.441906
# 2                                              0.327318
# 3                                              0.336764
# ...                                                 ...
# 1700                                           0.655137
# 1701                                           0.596690
# 1702                                           0.581484
# 1703                                           0.541772
#
#       Most people can be trusted, Gallup  \
# 0                                    NaN
# 1                               0.286315
# 2                               0.275833
# 3                                    NaN
# ...                                  ...
# 1700                                 NaN
# 1701                                 NaN
# 1702                                 NaN
# 1703                                 NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                         0.116683
# 1701                                         0.116683
# 1702                                         0.116683
# 1703                                         0.116683
#
#       Most people can be trusted, WVS round 2005-2009  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 2010-2014 Continent
# 0                                                 NaN      Asia
# 1                                                 NaN      Asia
# 2                                                 NaN      Asia
# 3                                                 NaN      Asia
# ...                                               ...       ...
# 1700                                         0.082942    Africa
# 1701                                         0.082942    Africa
# 1702                                         0.082942    Africa
# 1703                                         0.082942    Africa
#
# [1704 rows x 27 columns]

# %% [markdown]
# ## reviewing the data: the first five lines

# %%
data.head(5)
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
# 3                         51.919998                      0.495901    0.172137
# 4                         52.240002                      0.530935    0.244273
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# 0                   0.881686         0.517637         0.258195
# 1                   0.850035         0.583926         0.237092
# 2                   0.706766         0.618265         0.275324
# 3                   0.731109         0.611387         0.267175
# 4                   0.775620         0.710385         0.267919
#
#    Confidence in national government  Democratic Quality  Delivery Quality  \
# 0                           0.612072           -1.929690         -1.655084
# 1                           0.611545           -2.044093         -1.635025
# 2                           0.299357           -1.991810         -1.617176
# 3                           0.307386           -1.919018         -1.616221
# 4                           0.435440           -1.842996         -1.404078
#
#    Standard deviation of ladder by country-year  \
# 0                                      1.774662
# 1                                      1.722688
# 2                                      1.878622
# 3                                      1.785360
# 4                                      1.798283
#
#    Standard deviation/Mean of ladder by country-year  \
# 0                                           0.476600
# 1                                           0.391362
# 2                                           0.394803
# 3                                           0.465942
# 4                                           0.475367
#
#    GINI index (World Bank estimate)  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    GINI index (World Bank estimate), average 2000-16  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    gini of household income reported in Gallup, by wp5-year  \
# 0                                                NaN
# 1                                           0.441906
# 2                                           0.327318
# 3                                           0.336764
# 4                                           0.344540
#
#    Most people can be trusted, Gallup  \
# 0                                 NaN
# 1                            0.286315
# 2                            0.275833
# 3                                 NaN
# 4                                 NaN
#
#    Most people can be trusted, WVS round 1981-1984  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1989-1993  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1994-1998  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1999-2004  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 2005-2009  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 2010-2014 Continent
# 0                                              NaN      Asia
# 1                                              NaN      Asia
# 2                                              NaN      Asia
# 3                                              NaN      Asia
# 4                                              NaN      Asia

# %%
data.groupby(['Year','Continent'])['Life Ladder'].mean().reset_index().sample(5)
# Out:
#     Year      Continent  Life Ladder
# 31  2010         Europe     5.951117
# 72  2017           Asia     5.274848
# 65  2016         Africa     4.237311
# 35  2011         Africa     4.495338
# 32  2010  North America     6.299308

# %%
data.groupby(['Year','Continent'])['Life Ladder'].mean().reset_index()
# Out:
#     Year      Continent  Life Ladder
# 0   2005         Africa     5.167754
# 1   2005           Asia     5.804707
# 2   2005         Europe     6.649996
# 3   2005  North America     6.999353
# ..   ...            ...          ...
# 79  2018         Europe     6.377821
# 80  2018  North America     6.155330
# 81  2018        Oceania     7.273640
# 82  2018  South America     5.944915
#
# [83 rows x 3 columns]

# %% [markdown]
# ## reviewing the data: the last five lines

# %%
data.tail(5)
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 1699     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1702     Zimbabwe  2017     3.638300            7.549491        0.754147
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1699                         52.380001                      0.642034
# 1700                         53.799999                      0.667193
# 1701                         54.400002                      0.732971
# 1702                         55.000000                      0.752826
# 1703                         55.599998                      0.762675
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 1699   -0.048634                   0.820217         0.725214         0.239111
# 1700   -0.097354                   0.810457         0.715079         0.178861
# 1701   -0.068105                   0.723612         0.737636         0.208555
# 1702   -0.069670                   0.751208         0.806428         0.224051
# 1703   -0.038384                   0.844209         0.710119         0.211726
#
#       Confidence in national government  Democratic Quality  Delivery Quality  \
# 1699                           0.566209           -0.985267         -1.484067
# 1700                           0.590012           -0.893078         -1.357514
# 1701                           0.699344           -0.900649         -1.374650
# 1702                           0.682647           -0.988153         -1.350867
# 1703                           0.550508                 NaN               NaN
#
#       Standard deviation of ladder by country-year  \
# 1699                                      2.079248
# 1700                                      2.198865
# 1701                                      2.776363
# 1702                                      2.656848
# 1703                                      2.498696
#
#       Standard deviation/Mean of ladder by country-year  \
# 1699                                           0.496899
# 1700                                           0.593776
# 1701                                           0.743257
# 1702                                           0.730244
# 1703                                           0.690919
#
#       GINI index (World Bank estimate)  \
# 1699                               NaN
# 1700                               NaN
# 1701                               NaN
# 1702                               NaN
# 1703                               NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 1699                                              0.432
# 1700                                              0.432
# 1701                                              0.432
# 1702                                              0.432
# 1703                                              0.432
#
#       gini of household income reported in Gallup, by wp5-year  \
# 1699                                           0.601080
# 1700                                           0.655137
# 1701                                           0.596690
# 1702                                           0.581484
# 1703                                           0.541772
#
#       Most people can be trusted, Gallup  \
# 1699                                 NaN
# 1700                                 NaN
# 1701                                 NaN
# 1702                                 NaN
# 1703                                 NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 1699                                              NaN
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 1699                                              NaN
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 1699                                              NaN
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 1699                                         0.116683
# 1700                                         0.116683
# 1701                                         0.116683
# 1702                                         0.116683
# 1703                                         0.116683
#
#       Most people can be trusted, WVS round 2005-2009  \
# 1699                                              NaN
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 2010-2014 Continent
# 1699                                         0.082942    Africa
# 1700                                         0.082942    Africa
# 1701                                         0.082942    Africa
# 1702                                         0.082942    Africa
# 1703                                         0.082942    Africa

# %% [markdown]
# ## eviewing the data: five random lines

# %%
data.sample(5)
# Out:
#                  Country name  Year  Life Ladder  Log GDP per capita  \
# 794                    Kosovo  2011     4.859502            9.013744
# 193                    Brazil  2007     6.320673            9.493141
# 421        Dominican Republic  2013     5.015515            9.384899
# 1162  Palestinian Territories  2014     4.721938            8.370901
# 185                  Botswana  2012     4.835939            9.564126
#
#       Social support  Healthy life expectancy at birth  \
# 794         0.759102                         63.258301
# 193         0.886402                         63.779999
# 421         0.878449                         64.459999
# 1162        0.775087                               NaN
# 185         0.836743                         54.459999
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 794                       0.588979   -0.002332                   0.919212
# 193                       0.776645   -0.025988                   0.728038
# 421                       0.888566    0.019706                   0.751751
# 1162                      0.657050   -0.148277                   0.804165
# 185                       0.799410   -0.209502                   0.814423
#
#       Positive affect  Negative affect  Confidence in national government  \
# 794          0.695966         0.124438                                NaN
# 193          0.858976         0.299223                           0.383460
# 421          0.793314         0.295131                           0.570757
# 1162         0.565057         0.380452                           0.474314
# 185          0.773364         0.171257                           0.662238
#
#       Democratic Quality  Delivery Quality  \
# 794            -0.639118         -0.428707
# 193             0.090059         -0.171662
# 421             0.161399         -0.486398
# 1162           -1.433388         -0.235544
# 185             0.818506          0.672325
#
#       Standard deviation of ladder by country-year  \
# 794                                       2.068914
# 193                                       2.245499
# 421                                       2.795641
# 1162                                      2.402969
# 185                                       1.992194
#
#       Standard deviation/Mean of ladder by country-year  \
# 794                                            0.425746
# 193                                            0.355263
# 421                                            0.557399
# 1162                                           0.508895
# 185                                            0.411956
#
#       GINI index (World Bank estimate)  \
# 794                              0.278
# 193                              0.549
# 421                              0.470
# 1162                               NaN
# 185                                NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 794                                            0.289909
# 193                                            0.547286
# 421                                            0.484706
# 1162                                                NaN
# 185                                            0.626000
#
#       gini of household income reported in Gallup, by wp5-year  \
# 794                                            0.412191
# 193                                                 NaN
# 421                                            0.487150
# 1162                                           0.428933
# 185                                            0.581453
#
#       Most people can be trusted, Gallup  \
# 794                             0.067959
# 193                                  NaN
# 421                                  NaN
# 1162                                 NaN
# 185                                  NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 794                                               NaN
# 193                                               NaN
# 421                                               NaN
# 1162                                              NaN
# 185                                               NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 794                                               NaN
# 193                                           0.06602
# 421                                               NaN
# 1162                                              NaN
# 185                                               NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 794                                               NaN
# 193                                               NaN
# 421                                          0.251799
# 1162                                              NaN
# 185                                               NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 794                                               NaN
# 193                                               NaN
# 421                                               NaN
# 1162                                              NaN
# 185                                               NaN
#
#       Most people can be trusted, WVS round 2005-2009  \
# 794                                               NaN
# 193                                          0.093811
# 421                                               NaN
# 1162                                              NaN
# 185                                               NaN
#
#       Most people can be trusted, WVS round 2010-2014      Continent
# 794                                               NaN         Europe
# 193                                          0.070638  South America
# 421                                               NaN  North America
# 1162                                         0.158000           Asia
# 185                                               NaN         Africa

# %%
data.shape
# Out:
# (1704, 27)

# %%
data.columns
# Out:
# Index(['Country name', 'Year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality', 'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year',
#        'GINI index (World Bank estimate)',
#        'GINI index (World Bank estimate), average 2000-16',
#        'gini of household income reported in Gallup, by wp5-year',
#        'Most people can be trusted, Gallup',
#        'Most people can be trusted, WVS round 1981-1984',
#        'Most people can be trusted, WVS round 1989-1993',
#        'Most people can be trusted, WVS round 1994-1998',
#        'Most people can be trusted, WVS round 1999-2004',
#        'Most people can be trusted, WVS round 2005-2009',
#        'Most people can be trusted, WVS round 2010-2014', 'Continent'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 27 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Country name                                              1704 non-null   object
#  1   Year                                                      1704 non-null   int64
#  2   Life Ladder                                               1704 non-null   float64
#  3   Log GDP per capita                                        1676 non-null   float64
#  4   Social support                                            1691 non-null   float64
#  5   Healthy life expectancy at birth                          1676 non-null   float64
#  6   Freedom to make life choices                              1675 non-null   float64
#  7   Generosity                                                1622 non-null   float64
#  8   Perceptions of corruption                                 1608 non-null   float64
#  9   Positive affect                                           1685 non-null   float64
#  10  Negative affect                                           1691 non-null   float64
#  11  Confidence in national government                         1530 non-null   float64
#  12  Democratic Quality                                        1558 non-null   float64
#  13  Delivery Quality                                          1559 non-null   float64
#  14  Standard deviation of ladder by country-year              1704 non-null   float64
#  15  Standard deviation/Mean of ladder by country-year         1704 non-null   float64
#  16  GINI index (World Bank estimate)                          643 non-null    float64
#  17  GINI index (World Bank estimate), average 2000-16         1502 non-null   float64
#  18  gini of household income reported in Gallup, by wp5-year  1335 non-null   float64
#  19  Most people can be trusted, Gallup                        180 non-null    float64
#  20  Most people can be trusted, WVS round 1981-1984           125 non-null    float64
#  21  Most people can be trusted, WVS round 1989-1993           220 non-null    float64
#  22  Most people can be trusted, WVS round 1994-1998           618 non-null    float64
#  23  Most people can be trusted, WVS round 1999-2004           491 non-null    float64
#  24  Most people can be trusted, WVS round 2005-2009           630 non-null    float64
#  25  Most people can be trusted, WVS round 2010-2014           671 non-null    float64
#  26  Continent                                                 1704 non-null   object
# dtypes: float64(24), int64(1), object(2)
# memory usage: 359.6+ KB

# %% [markdown]
# ## data.sort_values() order the values in a ascending way,“Ascending” is True by default, ie, the lowest value first

# %%
data.sort_values(by=['Country name','Year'])
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# ...           ...   ...          ...                 ...             ...
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1702     Zimbabwe  2017     3.638300            7.549491        0.754147
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                            50.799999                      0.718114
# 1                            51.200001                      0.678896
# 2                            51.599998                      0.600127
# 3                            51.919998                      0.495901
# ...                                ...                           ...
# 1700                         53.799999                      0.667193
# 1701                         54.400002                      0.732971
# 1702                         55.000000                      0.752826
# 1703                         55.599998                      0.762675
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 0       0.177889                   0.881686         0.517637         0.258195
# 1       0.200178                   0.850035         0.583926         0.237092
# 2       0.134353                   0.706766         0.618265         0.275324
# 3       0.172137                   0.731109         0.611387         0.267175
# ...          ...                        ...              ...              ...
# 1700   -0.097354                   0.810457         0.715079         0.178861
# 1701   -0.068105                   0.723612         0.737636         0.208555
# 1702   -0.069670                   0.751208         0.806428         0.224051
# 1703   -0.038384                   0.844209         0.710119         0.211726
#
#       Confidence in national government  Democratic Quality  Delivery Quality  \
# 0                              0.612072           -1.929690         -1.655084
# 1                              0.611545           -2.044093         -1.635025
# 2                              0.299357           -1.991810         -1.617176
# 3                              0.307386           -1.919018         -1.616221
# ...                                 ...                 ...               ...
# 1700                           0.590012           -0.893078         -1.357514
# 1701                           0.699344           -0.900649         -1.374650
# 1702                           0.682647           -0.988153         -1.350867
# 1703                           0.550508                 NaN               NaN
#
#       Standard deviation of ladder by country-year  \
# 0                                         1.774662
# 1                                         1.722688
# 2                                         1.878622
# 3                                         1.785360
# ...                                            ...
# 1700                                      2.198865
# 1701                                      2.776363
# 1702                                      2.656848
# 1703                                      2.498696
#
#       Standard deviation/Mean of ladder by country-year  \
# 0                                              0.476600
# 1                                              0.391362
# 2                                              0.394803
# 3                                              0.465942
# ...                                                 ...
# 1700                                           0.593776
# 1701                                           0.743257
# 1702                                           0.730244
# 1703                                           0.690919
#
#       GINI index (World Bank estimate)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# ...                                ...
# 1700                               NaN
# 1701                               NaN
# 1702                               NaN
# 1703                               NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...                                                 ...
# 1700                                              0.432
# 1701                                              0.432
# 1702                                              0.432
# 1703                                              0.432
#
#       gini of household income reported in Gallup, by wp5-year  \
# 0                                                   NaN
# 1                                              0.441906
# 2                                              0.327318
# 3                                              0.336764
# ...                                                 ...
# 1700                                           0.655137
# 1701                                           0.596690
# 1702                                           0.581484
# 1703                                           0.541772
#
#       Most people can be trusted, Gallup  \
# 0                                    NaN
# 1                               0.286315
# 2                               0.275833
# 3                                    NaN
# ...                                  ...
# 1700                                 NaN
# 1701                                 NaN
# 1702                                 NaN
# 1703                                 NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                         0.116683
# 1701                                         0.116683
# 1702                                         0.116683
# 1703                                         0.116683
#
#       Most people can be trusted, WVS round 2005-2009  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 2010-2014 Continent
# 0                                                 NaN      Asia
# 1                                                 NaN      Asia
# 2                                                 NaN      Asia
# 3                                                 NaN      Asia
# ...                                               ...       ...
# 1700                                         0.082942    Africa
# 1701                                         0.082942    Africa
# 1702                                         0.082942    Africa
# 1703                                         0.082942    Africa
#
# [1704 rows x 27 columns]

# %%
data.sort_values(by='Year', ascending=True)
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 130       Belgium  2005     7.262290           10.591697        0.934875
# 397       Denmark  2005     8.018934           10.704770        0.972372
# 844       Lebanon  2005     5.491245            9.414857        0.796278
# 624       Hungary  2005     5.193933           10.019172        0.929628
# ...           ...   ...          ...                 ...             ...
# 568        Greece  2018     5.409289           10.132058        0.793501
# 1217  Philippines  2018     5.869173            8.985703        0.845803
# 518        Gambia  2018     4.922099            7.376554        0.684800
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 130                          69.900002                      0.923843
# 397                          69.599998                      0.971135
# 844                          64.599998                      0.703206
# 624                          64.599998                      0.696874
# ...                                ...                           ...
# 568                          72.400002                      0.564456
# 1217                         61.900002                      0.917808
# 518                          55.000000                      0.718729
# 1703                         55.599998                      0.762675
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 130          NaN                   0.597554         0.796279         0.260380
# 397          NaN                   0.236522         0.859549         0.153672
# 844          NaN                   0.945177         0.584244         0.292150
# 624          NaN                   0.902811         0.675444         0.290327
# ...          ...                        ...              ...              ...
# 568    -0.336385                   0.860302         0.665699         0.255007
# 1217   -0.113129                   0.726483         0.772846         0.393481
# 518          NaN                   0.691070         0.804012         0.379208
# 1703   -0.038384                   0.844209         0.710119         0.211726
#
#       Confidence in national government  Democratic Quality  Delivery Quality  \
# 130                            0.551705            1.108286          1.409674
# 397                            0.668683            1.407144          2.001794
# 844                                 NaN           -0.641525         -0.303633
# 624                            0.360526            1.089105          0.839862
# ...                                 ...                 ...               ...
# 568                            0.157049                 NaN               NaN
# 1217                           0.802007                 NaN               NaN
# 518                            0.757543                 NaN               NaN
# 1703                           0.550508                 NaN               NaN
#
#       Standard deviation of ladder by country-year  \
# 130                                       1.499964
# 397                                       1.340592
# 844                                       2.267514
# 624                                       2.069027
# ...                                            ...
# 568                                       2.079771
# 1217                                      2.700258
# 518                                       3.158858
# 1703                                      2.498696
#
#       Standard deviation/Mean of ladder by country-year  \
# 130                                            0.206541
# 397                                            0.167178
# 844                                            0.412933
# 624                                            0.398355
# ...                                                 ...
# 568                                            0.384481
# 1217                                           0.460075
# 518                                            0.641770
# 1703                                           0.690919
#
#       GINI index (World Bank estimate)  \
# 130                              0.293
# 397                              0.252
# 844                                NaN
# 624                              0.347
# ...                                ...
# 568                                NaN
# 1217                               NaN
# 518                                NaN
# 1703                               NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 130                                            0.284308
# 397                                            0.267000
# 844                                            0.318000
# 624                                            0.297917
# ...                                                 ...
# 568                                            0.346385
# 1217                                                NaN
# 518                                            0.422667
# 1703                                           0.432000
#
#       gini of household income reported in Gallup, by wp5-year  \
# 130                                                 NaN
# 397                                                 NaN
# 844                                                 NaN
# 624                                                 NaN
# ...                                                 ...
# 568                                            0.315494
# 1217                                           0.474452
# 518                                            0.592391
# 1703                                           0.541772
#
#       Most people can be trusted, Gallup  \
# 130                                  NaN
# 397                                  NaN
# 844                                  NaN
# 624                                  NaN
# ...                                  ...
# 568                                  NaN
# 1217                                 NaN
# 518                                  NaN
# 1703                                 NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                          0.331434
# ...                                               ...
# 568                                               NaN
# 1217                                              NaN
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                               NaN
# ...                                               ...
# 568                                               NaN
# 1217                                              NaN
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                          0.224615
# ...                                               ...
# 568                                               NaN
# 1217                                         0.055000
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                               NaN
# ...                                               ...
# 568                                               NaN
# 1217                                         0.082936
# 518                                               NaN
# 1703                                         0.116683
#
#       Most people can be trusted, WVS round 2005-2009  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                          0.288842
# ...                                               ...
# 568                                               NaN
# 1217                                              NaN
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 2010-2014 Continent
# 130                                               NaN    Europe
# 397                                               NaN    Europe
# 844                                          0.098333      Asia
# 624                                               NaN    Europe
# ...                                               ...       ...
# 568                                               NaN    Europe
# 1217                                         0.031518      Asia
# 518                                               NaN    Africa
# 1703                                         0.082942    Africa
#
# [1704 rows x 27 columns]

# %%
data.Year.head(5)
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# Name: Year, dtype: int64

# %%
data.iloc[10]
# Out:
# Country name                                       Afghanistan
# Year                                                      2018
# Life Ladder                                             2.6943
# Log GDP per capita                                     7.49459
#                                                       ...
# Most people can be trusted, WVS round 1999-2004            NaN
# Most people can be trusted, WVS round 2005-2009            NaN
# Most people can be trusted, WVS round 2010-2014            NaN
# Continent                                                 Asia
# Name: 10, Length: 27, dtype: object

# %%
data.set_index('Country name',inplace=True)

# %%
data.loc['United States']
# Out:
#                Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# United States  2006     7.181794           10.831686        0.964572
# United States  2007     7.512688           10.839805             NaN
# United States  2008     7.280386           10.827426        0.952587
# United States  2009     7.158032           10.790511        0.911794
# ...             ...          ...                 ...             ...
# United States  2015     6.863947           10.878154        0.903571
# United States  2016     6.803600           10.885554        0.896751
# United States  2017     6.991759           10.900906        0.921003
# United States  2018     6.882685           10.922465        0.903856
#
#                Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# United States                         68.059998                      0.911496
# United States                         68.220001                      0.871904
# United States                         68.379997                      0.877956
# United States                         68.540001                      0.830684
# ...                                         ...                           ...
# United States                         68.599998                      0.848753
# United States                         68.500000                      0.757893
# United States                         68.400002                      0.868497
# United States                         68.300003                      0.824607
#
#                Generosity  Perceptions of corruption  Positive affect  \
# Country name
# United States         NaN                   0.600309         0.827417
# United States    0.188272                   0.633035         0.828503
# United States    0.246029                   0.668495         0.871968
# United States    0.192269                   0.665394         0.843484
# ...                   ...                        ...              ...
# United States    0.210956                   0.697543         0.813908
# United States    0.135592                   0.738920         0.805674
# United States    0.188833                   0.681191         0.826555
# United States    0.107713                   0.709928         0.815383
#
#                Negative affect  Confidence in national government  \
# Country name
# United States         0.260511                           0.558029
# United States         0.231679                           0.393245
# United States         0.226823                           0.379221
# United States         0.261661                           0.503047
# ...                        ...                                ...
# United States         0.274688                           0.346936
# United States         0.264204                           0.297206
# United States         0.268269                           0.386535
# United States         0.292226                           0.313816
#
#                Democratic Quality  Delivery Quality  \
# Country name
# United States            0.797783          1.546490
# United States            0.742770          1.539012
# United States            0.864745          1.559145
# United States            0.772818          1.450143
# ...                           ...               ...
# United States            0.893903          1.428245
# United States            0.755765          1.491426
# United States            0.677056          1.552135
# United States                 NaN               NaN
#
#                Standard deviation of ladder by country-year  \
# Country name
# United States                                      1.873673
# United States                                      1.723988
# United States                                      1.778600
# United States                                      2.021277
# ...                                                     ...
# United States                                      1.953670
# United States                                      1.972203
# United States                                      1.880688
# United States                                      2.119374
#
#                Standard deviation/Mean of ladder by country-year  \
# Country name
# United States                                           0.260892
# United States                                           0.229477
# United States                                           0.244300
# United States                                           0.282379
# ...                                                          ...
# United States                                           0.284628
# United States                                           0.289876
# United States                                           0.268986
# United States                                           0.307928
#
#                GINI index (World Bank estimate)  \
# Country name
# United States                               NaN
# United States                             0.411
# United States                               NaN
# United States                               NaN
# ...                                         ...
# United States                               NaN
# United States                             0.415
# United States                               NaN
# United States                               NaN
#
#                GINI index (World Bank estimate), average 2000-16  \
# Country name
# United States                                           0.408167
# United States                                           0.408167
# United States                                           0.408167
# United States                                           0.408167
# ...                                                          ...
# United States                                           0.408167
# United States                                           0.408167
# United States                                           0.408167
# United States                                           0.408167
#
#                gini of household income reported in Gallup, by wp5-year  \
# Country name
# United States                                                NaN
# United States                                                NaN
# United States                                                NaN
# United States                                           0.705702
# ...                                                          ...
# United States                                           0.649792
# United States                                           0.693315
# United States                                           0.610804
# United States                                           0.701418
#
#                Most people can be trusted, Gallup  \
# Country name
# United States                                 NaN
# United States                                 NaN
# United States                                 NaN
# United States                            0.370746
# ...                                           ...
# United States                                 NaN
# United States                                 NaN
# United States                                 NaN
# United States                                 NaN
#
#                Most people can be trusted, WVS round 1981-1984  \
# Country name
# United States                                         0.453548
# United States                                         0.453548
# United States                                         0.453548
# United States                                         0.453548
# ...                                                        ...
# United States                                         0.453548
# United States                                         0.453548
# United States                                         0.453548
# United States                                         0.453548
#
#                Most people can be trusted, WVS round 1989-1993  \
# Country name
# United States                                              NaN
# United States                                              NaN
# United States                                              NaN
# United States                                              NaN
# ...                                                        ...
# United States                                              NaN
# United States                                              NaN
# United States                                              NaN
# United States                                              NaN
#
#                Most people can be trusted, WVS round 1994-1998  \
# Country name
# United States                                         0.349513
# United States                                         0.349513
# United States                                         0.349513
# United States                                         0.349513
# ...                                                        ...
# United States                                         0.349513
# United States                                         0.349513
# United States                                         0.349513
# United States                                         0.349513
#
#                Most people can be trusted, WVS round 1999-2004  \
# Country name
# United States                                         0.355185
# United States                                         0.355185
# United States                                         0.355185
# United States                                         0.355185
# ...                                                        ...
# United States                                         0.355185
# United States                                         0.355185
# United States                                         0.355185
# United States                                         0.355185
#
#                Most people can be trusted, WVS round 2005-2009  \
# Country name
# United States                                         0.393451
# United States                                         0.393451
# United States                                         0.393451
# United States                                         0.393451
# ...                                                        ...
# United States                                         0.393451
# United States                                         0.393451
# United States                                         0.393451
# United States                                         0.393451
#
#                Most people can be trusted, WVS round 2010-2014      Continent
# Country name
# United States                                         0.351395  North America
# United States                                         0.351395  North America
# United States                                         0.351395  North America
# United States                                         0.351395  North America
# ...                                                        ...            ...
# United States                                         0.351395  North America
# United States                                         0.351395  North America
# United States                                         0.351395  North America
# United States                                         0.351395  North America
#
# [13 rows x 26 columns]

# %%
data.describe()
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# count  1704.000000  1704.000000         1676.000000     1691.000000
# mean   2012.332160     5.437155            9.222456        0.810570
# std       3.688072     1.121149            1.185794        0.119210
# min    2005.000000     2.661718            6.457201        0.290184
# 25%    2009.000000     4.610970            8.304428        0.747512
# 50%    2012.000000     5.339557            9.406206        0.833098
# 75%    2015.000000     6.273522           10.193060        0.904432
# max    2018.000000     8.018934           11.770276        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1676.000000                   1675.000000
# mean                          63.111971                      0.733829
# std                            7.583622                      0.144115
# min                           32.299999                      0.257534
# 25%                           58.299999                      0.638436
# 50%                           65.000000                      0.752731
# 75%                           68.300003                      0.848155
# max                           76.800003                      0.985178
#
#         Generosity  Perceptions of corruption  Positive affect  \
# count  1622.000000                1608.000000      1685.000000
# mean      0.000079                   0.751315         0.709368
# std       0.163365                   0.186074         0.107984
# min      -0.336385                   0.035198         0.362498
# 25%      -0.115534                   0.696083         0.621855
# 50%      -0.022080                   0.805775         0.718541
# 75%       0.093522                   0.876458         0.801530
# max       0.677743                   0.983276         0.943621
#
#        Negative affect  Confidence in national government  Democratic Quality  \
# count      1691.000000                        1530.000000         1558.000000
# mean          0.265679                           0.481973           -0.136053
# std           0.084707                           0.192059            0.876074
# min           0.083426                           0.068769           -2.448228
# 25%           0.205414                           0.334735           -0.790461
# 50%           0.254544                           0.464109           -0.227386
# 75%           0.314896                           0.614862            0.650468
# max           0.704590                           0.993604            1.575009
#
#        Delivery Quality  Standard deviation of ladder by country-year  \
# count       1559.000000                                   1704.000000
# mean          -0.001390                                      2.026707
# std            0.975849                                      0.401484
# min           -2.144974                                      0.863034
# 25%           -0.711416                                      1.743369
# 50%           -0.218633                                      1.973070
# 75%            0.699971                                      2.242300
# max            2.184725                                      3.718958
#
#        Standard deviation/Mean of ladder by country-year  \
# count                                        1704.000000
# mean                                            0.392121
# std                                             0.124661
# min                                             0.133908
# 25%                                             0.310139
# 50%                                             0.372744
# 75%                                             0.456311
# max                                             1.022769
#
#        GINI index (World Bank estimate)  \
# count                        643.000000
# mean                           0.370000
# std                            0.083232
# min                            0.240000
# 25%                            0.305000
# 50%                            0.352000
# 75%                            0.428000
# max                            0.634000
#
#        GINI index (World Bank estimate), average 2000-16  \
# count                                        1502.000000
# mean                                            0.385438
# std                                             0.082396
# min                                             0.211000
# 25%                                             0.321429
# 50%                                             0.371000
# 75%                                             0.432200
# max                                             0.626000
#
#        gini of household income reported in Gallup, by wp5-year  \
# count                                        1335.000000
# mean                                            0.447771
# std                                             0.108505
# min                                             0.200969
# 25%                                             0.368424
# 50%                                             0.426541
# 75%                                             0.514803
# max                                             0.961435
#
#        Most people can be trusted, Gallup  \
# count                          180.000000
# mean                             0.226295
# std                              0.119079
# min                              0.066618
# 25%                              0.139773
# 50%                              0.198450
# 75%                              0.281627
# max                              0.640332
#
#        Most people can be trusted, WVS round 1981-1984  \
# count                                       125.000000
# mean                                          0.390480
# std                                           0.123309
# min                                           0.176535
# 25%                                           0.290300
# 50%                                           0.380174
# 75%                                           0.478149
# max                                           0.571719
#
#        Most people can be trusted, WVS round 1989-1993  \
# count                                       220.000000
# mean                                          0.283925
# std                                           0.113226
# min                                           0.066020
# 25%                                           0.223553
# 50%                                           0.292383
# 75%                                           0.341741
# max                                           0.594595
#
#        Most people can be trusted, WVS round 1994-1998  \
# count                                       618.000000
# mean                                          0.249574
# std                                           0.118126
# min                                           0.048720
# 25%                                           0.176876
# 50%                                           0.229924
# 75%                                           0.294242
# max                                           0.647737
#
#        Most people can be trusted, WVS round 1999-2004  \
# count                                       491.000000
# mean                                          0.268070
# std                                           0.145120
# min                                           0.075872
# 25%                                           0.155833
# 50%                                           0.232000
# 75%                                           0.385469
# max                                           0.637185
#
#        Most people can be trusted, WVS round 2005-2009  \
# count                                       630.000000
# mean                                          0.264336
# std                                           0.160169
# min                                           0.038242
# 25%                                           0.144976
# 50%                                           0.198380
# 75%                                           0.391370
# max                                           0.737305
#
#        Most people can be trusted, WVS round 2010-2014
# count                                       671.000000
# mean                                          0.237493
# std                                           0.157482
# min                                           0.031518
# 25%                                           0.118725
# 50%                                           0.193531
# 75%                                           0.335000
# max                                           0.661757

# %%
data.sort_values(by=['Country name','Year'], ascending=[True,True]).head(5)
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Afghanistan   2008     3.723590            7.168690        0.450662
# Afghanistan   2009     4.401778            7.333790        0.552308
# Afghanistan   2010     4.758381            7.386629        0.539075
# Afghanistan   2011     3.831719            7.415019        0.521104
# Afghanistan   2012     3.782938            7.517126        0.520637
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Afghanistan                          50.799999                      0.718114
# Afghanistan                          51.200001                      0.678896
# Afghanistan                          51.599998                      0.600127
# Afghanistan                          51.919998                      0.495901
# Afghanistan                          52.240002                      0.530935
#
#               Generosity  Perceptions of corruption  Positive affect  \
# Country name
# Afghanistan     0.177889                   0.881686         0.517637
# Afghanistan     0.200178                   0.850035         0.583926
# Afghanistan     0.134353                   0.706766         0.618265
# Afghanistan     0.172137                   0.731109         0.611387
# Afghanistan     0.244273                   0.775620         0.710385
#
#               Negative affect  Confidence in national government  \
# Country name
# Afghanistan          0.258195                           0.612072
# Afghanistan          0.237092                           0.611545
# Afghanistan          0.275324                           0.299357
# Afghanistan          0.267175                           0.307386
# Afghanistan          0.267919                           0.435440
#
#               Democratic Quality  Delivery Quality  \
# Country name
# Afghanistan            -1.929690         -1.655084
# Afghanistan            -2.044093         -1.635025
# Afghanistan            -1.991810         -1.617176
# Afghanistan            -1.919018         -1.616221
# Afghanistan            -1.842996         -1.404078
#
#               Standard deviation of ladder by country-year  \
# Country name
# Afghanistan                                       1.774662
# Afghanistan                                       1.722688
# Afghanistan                                       1.878622
# Afghanistan                                       1.785360
# Afghanistan                                       1.798283
#
#               Standard deviation/Mean of ladder by country-year  \
# Country name
# Afghanistan                                            0.476600
# Afghanistan                                            0.391362
# Afghanistan                                            0.394803
# Afghanistan                                            0.465942
# Afghanistan                                            0.475367
#
#               GINI index (World Bank estimate)  \
# Country name
# Afghanistan                                NaN
# Afghanistan                                NaN
# Afghanistan                                NaN
# Afghanistan                                NaN
# Afghanistan                                NaN
#
#               GINI index (World Bank estimate), average 2000-16  \
# Country name
# Afghanistan                                                 NaN
# Afghanistan                                                 NaN
# Afghanistan                                                 NaN
# Afghanistan                                                 NaN
# Afghanistan                                                 NaN
#
#               gini of household income reported in Gallup, by wp5-year  \
# Country name
# Afghanistan                                                 NaN
# Afghanistan                                            0.441906
# Afghanistan                                            0.327318
# Afghanistan                                            0.336764
# Afghanistan                                            0.344540
#
#               Most people can be trusted, Gallup  \
# Country name
# Afghanistan                                  NaN
# Afghanistan                             0.286315
# Afghanistan                             0.275833
# Afghanistan                                  NaN
# Afghanistan                                  NaN
#
#               Most people can be trusted, WVS round 1981-1984  \
# Country name
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
#
#               Most people can be trusted, WVS round 1989-1993  \
# Country name
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
#
#               Most people can be trusted, WVS round 1994-1998  \
# Country name
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
#
#               Most people can be trusted, WVS round 1999-2004  \
# Country name
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
#
#               Most people can be trusted, WVS round 2005-2009  \
# Country name
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
#
#               Most people can be trusted, WVS round 2010-2014 Continent
# Country name
# Afghanistan                                               NaN      Asia
# Afghanistan                                               NaN      Asia
# Afghanistan                                               NaN      Asia
# Afghanistan                                               NaN      Asia
# Afghanistan                                               NaN      Asia

# %%
data.sort_values(by=['Country name','Year'], ascending=[False,True]).head(5)
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Zimbabwe      2006     3.826268            7.366704        0.821656
# Zimbabwe      2007     3.280247            7.313939        0.828113
# Zimbabwe      2008     3.174264            7.102516        0.843475
# Zimbabwe      2009     4.055914            7.197595        0.805781
# Zimbabwe      2010     4.681570            7.296330        0.856638
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Zimbabwe                             41.580002                      0.431110
# Zimbabwe                             42.860001                      0.455957
# Zimbabwe                             44.139999                      0.343556
# Zimbabwe                             45.419998                      0.411089
# Zimbabwe                             46.700001                      0.664718
#
#               Generosity  Perceptions of corruption  Positive affect  \
# Country name
# Zimbabwe       -0.056554                   0.904757         0.715229
# Zimbabwe       -0.061563                   0.946287         0.660861
# Zimbabwe       -0.068002                   0.963846         0.630983
# Zimbabwe       -0.055836                   0.930818         0.735503
# Zimbabwe       -0.066457                   0.828361         0.747702
#
#               Negative affect  Confidence in national government  \
# Country name
# Zimbabwe             0.297147                           0.317073
# Zimbabwe             0.264989                           0.225752
# Zimbabwe             0.250060                           0.181594
# Zimbabwe             0.218419                           0.285287
# Zimbabwe             0.122150                           0.471201
#
#               Democratic Quality  Delivery Quality  \
# Country name
# Zimbabwe               -1.236102         -1.570760
# Zimbabwe               -1.340245         -1.653740
# Zimbabwe               -1.381488         -1.701545
# Zimbabwe               -1.353181         -1.717821
# Zimbabwe               -1.289599         -1.693678
#
#               Standard deviation of ladder by country-year  \
# Country name
# Zimbabwe                                          2.013538
# Zimbabwe                                          1.929571
# Zimbabwe                                          1.685007
# Zimbabwe                                          2.024098
# Zimbabwe                                          1.511014
#
#               Standard deviation/Mean of ladder by country-year  \
# Country name
# Zimbabwe                                               0.526241
# Zimbabwe                                               0.588240
# Zimbabwe                                               0.530834
# Zimbabwe                                               0.499048
# Zimbabwe                                               0.322758
#
#               GINI index (World Bank estimate)  \
# Country name
# Zimbabwe                                   NaN
# Zimbabwe                                   NaN
# Zimbabwe                                   NaN
# Zimbabwe                                   NaN
# Zimbabwe                                   NaN
#
#               GINI index (World Bank estimate), average 2000-16  \
# Country name
# Zimbabwe                                                  0.432
# Zimbabwe                                                  0.432
# Zimbabwe                                                  0.432
# Zimbabwe                                                  0.432
# Zimbabwe                                                  0.432
#
#               gini of household income reported in Gallup, by wp5-year  \
# Country name
# Zimbabwe                                                    NaN
# Zimbabwe                                                    NaN
# Zimbabwe                                                    NaN
# Zimbabwe                                               0.545112
# Zimbabwe                                               0.680030
#
#               Most people can be trusted, Gallup  \
# Country name
# Zimbabwe                                     NaN
# Zimbabwe                                     NaN
# Zimbabwe                                     NaN
# Zimbabwe                                0.148151
# Zimbabwe                                     NaN
#
#               Most people can be trusted, WVS round 1981-1984  \
# Country name
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
#
#               Most people can be trusted, WVS round 1989-1993  \
# Country name
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
#
#               Most people can be trusted, WVS round 1994-1998  \
# Country name
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
#
#               Most people can be trusted, WVS round 1999-2004  \
# Country name
# Zimbabwe                                             0.116683
# Zimbabwe                                             0.116683
# Zimbabwe                                             0.116683
# Zimbabwe                                             0.116683
# Zimbabwe                                             0.116683
#
#               Most people can be trusted, WVS round 2005-2009  \
# Country name
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
#
#               Most people can be trusted, WVS round 2010-2014 Continent
# Country name
# Zimbabwe                                             0.082942    Africa
# Zimbabwe                                             0.082942    Africa
# Zimbabwe                                             0.082942    Africa
# Zimbabwe                                             0.082942    Africa
# Zimbabwe                                             0.082942    Africa

# %%
data.sample(5)
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Greece        2016     5.302619           10.094593        0.802606
# Paraguay      2014     5.118642            9.048003        0.959250
# Latvia        2011     4.966812            9.892092        0.836042
# Ghana         2013     4.965053            8.244687        0.676289
# Nicaragua     2015     5.924113            8.508540        0.826909
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Greece                               72.000000                      0.481617
# Paraguay                             64.980003                      0.759396
# Latvia                               64.860001                      0.564464
# Ghana                                55.240002                      0.793794
# Nicaragua                            66.599998                      0.809259
#
#               Generosity  Perceptions of corruption  Positive affect  \
# Country name
# Greece         -0.261434                   0.898471         0.700504
# Paraguay        0.010721                   0.762376         0.943621
# Latvia         -0.005148                   0.934256         0.563278
# Ghana          -0.058682                   0.880178         0.690766
# Nicaragua       0.078000                   0.727998         0.796685
#
#               Negative affect  Confidence in national government  \
# Country name
# Greece               0.336208                           0.132487
# Paraguay             0.215778                           0.193542
# Latvia               0.221713                           0.107237
# Ghana                0.210819                           0.485888
# Nicaragua            0.345595                           0.603455
#
#               Democratic Quality  Delivery Quality  \
# Country name
# Greece                  0.273432          0.097654
# Paraguay               -0.095735         -0.711251
# Latvia                  0.528389          0.672904
# Ghana                   0.249730          0.009688
# Nicaragua              -0.250674         -0.708666
#
#               Standard deviation of ladder by country-year  \
# Country name
# Greece                                            2.317298
# Paraguay                                          1.927594
# Latvia                                            1.912062
# Ghana                                             1.828295
# Nicaragua                                         2.909446
#
#               Standard deviation/Mean of ladder by country-year  \
# Country name
# Greece                                                 0.437010
# Paraguay                                               0.376583
# Latvia                                                 0.384968
# Ghana                                                  0.368233
# Nicaragua                                              0.491119
#
#               GINI index (World Bank estimate)  \
# Country name
# Greece                                     NaN
# Paraguay                                 0.507
# Latvia                                   0.358
# Ghana                                      NaN
# Nicaragua                                  NaN
#
#               GINI index (World Bank estimate), average 2000-16  \
# Country name
# Greece                                                 0.346385
# Paraguay                                               0.513312
# Latvia                                                 0.360333
# Ghana                                                  0.426000
# Nicaragua                                              0.479500
#
#               gini of household income reported in Gallup, by wp5-year  \
# Country name
# Greece                                                 0.317849
# Paraguay                                               0.421719
# Latvia                                                 0.333452
# Ghana                                                  0.544950
# Nicaragua                                              0.531768
#
#               Most people can be trusted, Gallup  \
# Country name
# Greece                                       NaN
# Paraguay                                     NaN
# Latvia                                       NaN
# Ghana                                        NaN
# Nicaragua                                    NaN
#
#               Most people can be trusted, WVS round 1981-1984  \
# Country name
# Greece                                                    NaN
# Paraguay                                                  NaN
# Latvia                                                    NaN
# Ghana                                                     NaN
# Nicaragua                                                 NaN
#
#               Most people can be trusted, WVS round 1989-1993  \
# Country name
# Greece                                                    NaN
# Paraguay                                                  NaN
# Latvia                                                    NaN
# Ghana                                                     NaN
# Nicaragua                                                 NaN
#
#               Most people can be trusted, WVS round 1994-1998  \
# Country name
# Greece                                                    NaN
# Paraguay                                                  NaN
# Latvia                                               0.239167
# Ghana                                                     NaN
# Nicaragua                                                 NaN
#
#               Most people can be trusted, WVS round 1999-2004  \
# Country name
# Greece                                                    NaN
# Paraguay                                                  NaN
# Latvia                                                    NaN
# Ghana                                                     NaN
# Nicaragua                                                 NaN
#
#               Most people can be trusted, WVS round 2005-2009  \
# Country name
# Greece                                                    NaN
# Paraguay                                                  NaN
# Latvia                                                    NaN
# Ghana                                                0.084801
# Nicaragua                                                 NaN
#
#               Most people can be trusted, WVS round 2010-2014      Continent
# Country name
# Greece                                                    NaN         Europe
# Paraguay                                                  NaN  South America
# Latvia                                                    NaN         Europe
# Ghana                                                0.050309         Africa
# Nicaragua                                                 NaN  North America

# %%
data.groupby(['Year','Continent'])['Log GDP per capita'].idxmax()
# Out:
# Year  Continent
# 2005  Africa                   Egypt
#       Asia              Saudi Arabia
#       Europe                 Denmark
#       North America           Canada
#                            ...
# 2018  Europe              Luxembourg
#       North America    United States
#       Oceania              Australia
#       South America            Chile
# Name: Log GDP per capita, Length: 83, dtype: object

# %%
data.groupby(['Year','Continent'])['Life Ladder'].idxmax()
# Out:
# Year  Continent
# 2005  Africa                  Egypt
#       Asia             Saudi Arabia
#       Europe                Denmark
#       North America          Canada
#                            ...
# 2018  Europe                Finland
#       North America          Canada
#       Oceania           New Zealand
#       South America           Chile
# Name: Life Ladder, Length: 83, dtype: object

# %%
data.groupby(['Year','Continent'])['Social support'].idxmax()
# Out:
# Year  Continent
# 2005  Africa                    Egypt
#       Asia                      Japan
#       Europe           United Kingdom
#       North America            Canada
#                             ...
# 2018  Europe                   Norway
#       North America            Canada
#       Oceania             New Zealand
#       South America           Uruguay
# Name: Social support, Length: 83, dtype: object

# %%
data.groupby(['Year','Continent'])['Healthy life expectancy at birth'].idxmax()
# Out:
# Year  Continent
# 2005  Africa               Egypt
#       Asia                 Japan
#       Europe               Italy
#       North America       Canada
#                          ...
# 2018  Europe               Spain
#       North America       Canada
#       Oceania          Australia
#       South America        Chile
# Name: Healthy life expectancy at birth, Length: 83, dtype: object

# %%
data.groupby(['Year','Continent'])['Confidence in national government'].idxmax()
# Out:
# Year  Continent
# 2005  Africa                   NaN
#       Asia                  Jordan
#       Europe               Denmark
#       North America         Canada
#                           ...
# 2018  Europe           Switzerland
#       North America         Canada
#       Oceania          New Zealand
#       South America        Ecuador
# Name: Confidence in national government, Length: 83, dtype: object

# %%
data.groupby(['Year','Continent'])['Confidence in national government'].idxmax()
# Out:
# Year  Continent
# 2005  Africa                   NaN
#       Asia                  Jordan
#       Europe               Denmark
#       North America         Canada
#                           ...
# 2018  Europe           Switzerland
#       North America         Canada
#       Oceania          New Zealand
#       South America        Ecuador
# Name: Confidence in national government, Length: 83, dtype: object
